# %%
! git clone https://github.com/GauthamrajMolkod/imageprocessinglab/blob/main/bank.csv
# Out:
# Cloning into 'bank.csv'...
# fatal: repository 'https://github.com/GauthamrajMolkod/imageprocessinglab/blob/main/bank.csv/' not found

# %%
urlfile="https://github.com/GauthamrajMolkod/imageprocessinglab/blob/main/bank.csv"
read_csv(url(urlfile))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ba459ee533bf> in <cell line: 2>()
#       1 urlfile="https://github.com/GauthamrajMolkod/imageprocessinglab/blob/main/bank.csv"
# ----> 2 read_csv(url(urlfile))
#
# NameError: name 'read_csv' is not defined
