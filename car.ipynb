# %% [markdown]
# 2. USe a Car.csv dataset and perform exploratory data analysis using pandas and matplotlib libarary functions to manipulate and visualize the data and find insights

# %% [markdown]
# 1.Import the libraries

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
dft=pd.read_csv('/content/gdrive/MyDrive/car.csv')

# %% [markdown]
# 2.Load the dtaaset using pandas read.csv() function

# %%
car=pd.read_csv('/content/gdrive/MyDrive/car.csv')
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# 3. Display the head of the dataset using the head() function

# %%
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# 4. Display the bottom 5 rowa of the dataset using the tail() function

# %%
car.tail(5)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %% [markdown]
# 5.Print  summary statistics of the dtaset using the describe() function

# %%
car.describe(include='all')
# Out:
#        Car_Name         Year  Selling_Price  Present_Price     Kms_Driven  \
# count       301   301.000000     301.000000     301.000000     301.000000
# unique       98          NaN            NaN            NaN            NaN
# top        city          NaN            NaN            NaN            NaN
# freq         26          NaN            NaN            NaN            NaN
# mean        NaN  2013.627907       4.661296       7.628472   36947.205980
# std         NaN     2.891554       5.082812       8.644115   38886.883882
# min         NaN  2003.000000       0.100000       0.320000     500.000000
# 25%         NaN  2012.000000       0.900000       1.200000   15000.000000
# 50%         NaN  2014.000000       3.600000       6.400000   32000.000000
# 75%         NaN  2016.000000       6.000000       9.900000   48767.000000
# max         NaN  2018.000000      35.000000      92.600000  500000.000000
#
#        Fuel_Type Seller_Type Transmission       Owner
# ...

# %% [markdown]
# 6.Plot a histogram for all the variables

# %%
car.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Selling_Price'}>],
#        [<Axes: title={'center': 'Present_Price'}>,
#         <Axes: title={'center': 'Kms_Driven'}>],
#        [<Axes: title={'center': 'Owner'}>, <Axes: >]], dtype=object)

# %% [markdown]
# 7.Box Plot to visualize the relationship between vehicle size and engine hp

# %%
sns.boxplot(x="Selling_Price",y="Present_Price",data=car)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Present_Price'>

# %% [markdown]
# 8.Build a pair plot using seaborn libraray

# %%
sns.pairplot(car)

# %% [markdown]
# 9.Drop irrelevant columns frm the dataset using drop() function

# %%
car=car.drop(['Owner','Fuel_Type'],axis=1)
car.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-38ec99dcec2c> in <cell line: 1>()
# ----> 1 car=car.drop(['Owner','Fuel_Type'],axis=1)
#       2 car.head(5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
dft
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# 10. Use rename() function to rename the columns

# %%
car=car.rename(columns={"Selling_Price":"sell_price","Present_Price":"prsnt_price"})
car.head(5)
# Out:
#   Car_Name  Year  sell_price  prsnt_price  Kms_Driven Seller_Type Transmission
# 0     ritz  2014        3.35         5.59       27000      Dealer       Manual
# 1      sx4  2013        4.75         9.54       43000      Dealer       Manual
# 2     ciaz  2017        7.25         9.85        6900      Dealer       Manual
# 3  wagon r  2011        2.85         4.15        5200      Dealer       Manual
# 4    swift  2014        4.60         6.87       42450      Dealer       Manual

# %% [markdown]
# 11.Print the total number of duplicate data

# %%
duplicate_rows_car=car[car.duplicated()]
print("number of duplicate rows:",duplicate_rows_car.shape)
car.count()
# Out:
# number of duplicate rows: (2, 7)
# Car_Name        301
# Year            301
# sell_price      301
# prsnt_price     301
# Kms_Driven      301
# Seller_Type     301
# Transmission    301
# dtype: int64

# %% [markdown]
# 12.Remove the Duplicate rows using the drop_duplicates() function

# %%
car=car.drop_duplicates()
car.head()
# Out:
#   Car_Name  Year  sell_price  prsnt_price  Kms_Driven Seller_Type Transmission
# 0     ritz  2014        3.35         5.59       27000      Dealer       Manual
# 1      sx4  2013        4.75         9.54       43000      Dealer       Manual
# 2     ciaz  2017        7.25         9.85        6900      Dealer       Manual
# 3  wagon r  2011        2.85         4.15        5200      Dealer       Manual
# 4    swift  2014        4.60         6.87       42450      Dealer       Manual

# %% [markdown]
# 13. Drop the missing values from the dataset

# %%
print(car.isnull().sum())
# Out:
# Car_Name        0
# Year            0
# sell_price      0
# prsnt_price     0
# Kms_Driven      0
# Seller_Type     0
# Transmission    0
# dtype: int64

# %%
car=car.dropna()
car.count()
# Out:
# Car_Name        299
# Year            299
# sell_price      299
# prsnt_price     299
# Kms_Driven      299
# Seller_Type     299
# Transmission    299
# dtype: int64

# %% [markdown]
# 14. Plot a histogram to find the number of cars per brand

# %%
car.Year.value_counts().nlargest(40).plot(kind='bar',figsize=(10,5))
plt.title("Number of car by year")
plt.ylabel("Number of cars")
plt.xlabel("year");

# %% [markdown]
# 15.Draw a correlation plot between variables

# %%
plt.figure(figsize=(20,10))
c=car.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# <ipython-input-52-56b7c5973d67>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=car.corr()
#                  Year  sell_price  prsnt_price  Kms_Driven
# Year         1.000000    0.234369    -0.053563   -0.525714
# sell_price   0.234369    1.000000     0.876378    0.028566
# prsnt_price -0.053563    0.876378     1.000000    0.205253
# Kms_Driven  -0.525714    0.028566     0.205253    1.000000
