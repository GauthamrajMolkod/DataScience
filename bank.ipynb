# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
from pandas import DataFrame

# %%
bank=pd.read_csv("/content/gdrive/MyDrive/bank.csv")
